# %%
from fastai.vision.all import *
from fastai.vision.widgets import *

# %%
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila

# %%
#!ls ../input/2production
# Out:
# __notebook__.ipynb	   __results__.html   custom.css
# __notebook_source__.ipynb  __results___files  export.pkl
# __output__.json		   bears	      images

# %%
#path = Path()
learn_inf = load_learner('../input/2production/export.pkl', cpu=True)
btn_upload = widgets.FileUpload()
out_pl = widgets.Output()
lbl_pred = widgets.Label()

# %%
def on_data_change(change):
    lbl_pred.value = ''
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

# %%
btn_upload.observe(on_data_change, names=['data'])

# %%
display(VBox([widgets.Label('Select your bear!'), btn_upload, out_pl, lbl_pred]))
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={}, description='Upload'), Output(), Label(v…

# %%
# Out:
# Collecting voila
#   Downloading voila-0.2.3-py3-none-any.whl (6.9 MB)
#      |████████████████████████████████| 6.9 MB 2.7 MB/s eta 0:00:01
# Collecting nbclient<0.6,>=0.4.0
#   Downloading nbclient-0.5.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.1 MB/s  eta 0:00:01
# Collecting nbconvert<7,>=6.0.0
#   Downloading nbconvert-6.0.6-py3-none-any.whl (551 kB)
#      |████████████████████████████████| 551 kB 42.3 MB/s eta 0:00:01
# Requirement already satisfied: jupyter-client<7,>=6.1.3 in /opt/conda/lib/python3.7/site-packages (from voila) (6.1.3)
# Collecting jupyter-server<2.0.0,>=0.3.0
#   Downloading jupyter_server-1.0.1-py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 34.9 MB/s eta 0:00:01
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.7/site-packages (from nbclient<0.6,>=0.4.0->voila) (1.3.2)
# Requirement already satisfied: async-generator in /opt/conda/lib/python3.7/site-packages (from nbclient<0.6,>=0.4.0->voila) (1.10)
# Requirement already satisfied: nbformat>=5.0 in /opt/conda/lib/python3.7/site-packages (from nbclient<0.6,>=0.4.0->voila) (5.0.6)
# Requirement already satisfied: traitlets>=4.2 in /opt/conda/lib/python3.7/site-packages (from nbclient<0.6,>=0.4.0->voila) (4.3.3)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (3.1.4)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.1.1-py2.py3-none-any.whl (4.6 kB)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (4.6.3)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (1.4.2)
# Requirement already satisfied: pygments>=2.4.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (2.6.1)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (0.8.4)
# Requirement already satisfied: jinja2>=2.4 in /opt/conda/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (2.11.2)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/lib/python3.7/site-packages (from jupyter-client<7,>=6.1.3->voila) (2.8.1)
# Requirement already satisfied: tornado>=4.1 in /opt/conda/lib/python3.7/site-packages (from jupyter-client<7,>=6.1.3->voila) (5.0.2)
# Requirement already satisfied: pyzmq>=13 in /opt/conda/lib/python3.7/site-packages (from jupyter-client<7,>=6.1.3->voila) (19.0.0)
# Requirement already satisfied: Send2Trash in /opt/conda/lib/python3.7/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.7/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.8.3)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.7/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.2.0)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.7/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.7/site-packages (from nbformat>=5.0->nbclient<0.6,>=0.4.0->voila) (3.2.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from traitlets>=4.2->nbclient<0.6,>=0.4.0->voila) (1.14.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.7/site-packages (from traitlets>=4.2->nbclient<0.6,>=0.4.0->voila) (4.4.2)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (0.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2>=2.4->nbconvert<7,>=6.0.0->voila) (1.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=5.0->nbclient<0.6,>=0.4.0->voila) (0.16.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=5.0->nbclient<0.6,>=0.4.0->voila) (1.6.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=5.0->nbclient<0.6,>=0.4.0->voila) (19.3.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=5.0->nbclient<0.6,>=0.4.0->voila) (46.1.3.post20200325)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=5.0->nbclient<0.6,>=0.4.0->voila) (3.1.0)
# Installing collected packages: nbclient, jupyterlab-pygments, nbconvert, jupyter-server, voila
#   Attempting uninstall: nbclient
#     Found existing installation: nbclient 0.2.0
#     Uninstalling nbclient-0.2.0:
#       Successfully uninstalled nbclient-0.2.0
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# nbclient 0.5.0 requires jupyter-client>=6.1.5, but you'll have jupyter-client 6.1.3 which is incompatible.
# jupyterlab-git 0.10.0 requires nbdime<2.0.0,>=1.1.0, but you'll have nbdime 2.0.0 which is incompatible.
# Successfully installed jupyter-server-1.0.1 jupyterlab-pygments-0.1.1 nbclient-0.5.0 nbconvert-6.0.6 voila-0.2.3
# Enabling: voila
# - Writing config: /opt/conda/etc/jupyter
#     - Validating...
#       voila 0.2.3 OK
